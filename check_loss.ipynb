# %%
cd /disk107/raw_data/unet_speech/
# Out:
# /disk107/raw_data/unet_speech

# %%
import numpy as np
import matplotlib.pyplot as plt

# npz = np.load('./model/loss_20210203_103808.npz')
# npz = np.load('./model/loss_20210203_090041.npz')
npz = np.load('./model/loss_20210203_123305.npz')


train_loss = npz['train_loss']
val_loss = npz['val_loss']

mim_loss = np.min(val_loss)
print("min:",np.min(val_loss))

p1=plt.plot(train_loss)
p2=plt.plot(val_loss)
plt.legend((p1[0], p2[0]), ("train_loss", "val_loss"), loc=1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# min: 0.0014060718152442918
